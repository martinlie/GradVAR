# %% [markdown]
# # Forecast example
# This notebook demonstrates how train a model, and to generate forecasts using a trained model on three distinct sinusoidal curves. One of the curves is a composite signal, formed by combining two sine waves with different frequencies.
#
# Be sure to have extra libraries installed:
#
# !pip install matplotlib

# %%
import jax.numpy as jnp
import jax.random as jr
from gradvar.gradvar import GradVAR
from gradvar.earlystopping import EarlyStopping
import matplotlib.pyplot as plt
jnp.set_printoptions(suppress=True)

# %%
def generate_sinusoidal_data(T, noise_std=0.05, key=jr.PRNGKey(0)):
    """ Generate a 2D time series: one sine and one cosine wave with noise """
    t1 = jnp.linspace(-jnp.pi * 8, jnp.pi * 8, T)
    t2 = jnp.linspace(-jnp.pi * 2, jnp.pi * 2, T)
    t3 = jnp.linspace(-jnp.pi * 4, jnp.pi * 4, T)
    noise = noise_std * jr.normal(key, (3, T))
    Y = jnp.stack([jnp.sin(t1)*0.5, jnp.cos(t2), jnp.sin(t3) + jnp.sin(t3*1.5)]) + noise
    return Y.T

# %% [markdown]
# ## Example data
# We generate a sinusoidal dataset $Y$ with some added noise, where data is inputted as a matrix of $m \times n$ where $m$ is the time dimension (rows) with $t_0$ being the first row, and $n$ the signal columns.

# %%
key = jr.PRNGKey(42)
Y = generate_sinusoidal_data(T = 400, noise_std=0.05, key=key)
plt.plot(Y)
plt.show()

# %% [markdown]
# ## Training
# The `train()`-function prepares the input dataset using the `p`-parameter (number of lags), and train the VAR model up until the number of epochs specified. Alternatively, as done here, we can define and early stopping scheme where we stop training when the losses flattens out.

# %%
av = GradVAR()
losses, *_ = av.train(Y, p=50, learning_rate=0.001, num_epochs=10000, early_stopping = EarlyStopping(patience=30, min_delta=1e-5))
# Out:
#  11%|█▏        | 1143/10000 [01:06<08:31, 17.31it/s]

# %% [markdown]
# We can now plot the loss curve and determine convergency, as we see the curve flattens and training terminates early:

# %%
plt.plot(losses)
plt.show()

# %% [markdown]
# ## Forecasting with the model
# This example let the model forecast the future development of the signal interactions, in this case we use the 50 last lags to predict the next 250 steps by auto-regression:

# %%
Y_forecast = av.forecast(Y, 250)

x_data = jnp.arange(len(Y))
x_forecast = jnp.arange(len(Y), len(Y) + len(Y_forecast))

plt.figure(figsize=(8, 4))
plt.plot(x_data, Y[:,0], color='blue')
plt.plot(x_data, Y[:,1], color='orange')
plt.plot(x_data, Y[:,2], color='red')
plt.plot(x_forecast, Y_forecast[:,0], color='blue', linestyle='--')
plt.plot(x_forecast, Y_forecast[:,1], color='orange', linestyle='--')
plt.plot(x_forecast, Y_forecast[:,2], color='red', linestyle='--')

plt.axvline(x=len(Y)-1, color='gray', linestyle='dashed', label="Forecast Start")
plt.show()
